# %%
import numpy as np
import os

import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
matplotlib.rcParams['figure.figsize'] = (8,4)

# %%
FREQ = 1.3e9
OMEGA = 2*np.pi*FREQ
c_light = 299792458.

MU0 = 4e-7*np.pi


LINES = open('1T9.T7').readlines()

LINES[0:3], LINES[3:10]
# Out:
# (['0 134.7 1347\n', '1300.0\n', '0 3.9 39\n'],
#  ['-2.108881786851425e-10 0.0 0\n',
#   '-0.0\n',
#   '-2.1106466961613225e-10 0.0 0\n',
#   '-0.0\n',
#   '-2.1195427930882333e-10 0.0 0\n',
#   '-0.0\n',
#   '-2.135582002695064e-10 0.0 0\n'])

# %%
nz = int(LINES[0].split()[-1]) +1
nr = int(LINES[2].split()[-1]) +1
nz, nr
# Out:
# (1348, 40)

# %%
(len(LINES) -3)/2
# Out:
# 53920.0

# %%
with open('temp', 'w') as f:
    for l in LINES[4::2]:
        f.write(l)
        
dat = np.loadtxt('temp', ndmin=1)        
H  = dat.reshape(nr, nz)

# %%
with open('temp', 'w') as f:
    for l in LINES[3::2]:
        f.write(l)
        
dat = np.loadtxt('temp', ndmin=1).T       
dat.shape
Ez  = dat[0].reshape(nr, nz)        
Er  = dat[1].reshape(nr, nz)

# %%
plt.imshow(H)

# %%
#plt.plot(Ez[0, :])
plt.plot(Ez[0, :])
plt.plot(H[10, :]/800)

# %%
plt.plot(H[1, :]*MU0)

# %%
plt.plot(Ez[0, :]*1e6)

# %%
plt.plot(Er[1, :]*1e6)

# %%
Ez[0, :]
# Out:
# array([-2.10888179e-10, -2.11064670e-10, -2.11954279e-10, ...,
#        -2.16023707e-10, -2.14943296e-10, -2.14590314e-10])
