# %%
# Useful for debugging
# %load_ext autoreload
# %autoreload 2

# %%
from impact.parsers import fort_files, load_fort, load_many_fort

# %%
opath = '../templates/lcls_injector/output/'

# Find fort.X output files in path
fortfiles=fort_files(opath)
fortfiles
# Out:
# ['../templates/lcls_injector/output/fort.30',
#  '../templates/lcls_injector/output/fort.40',
#  '../templates/lcls_injector/output/fort.25',
#  '../templates/lcls_injector/output/fort.70',
#  '../templates/lcls_injector/output/fort.24',
#  '../templates/lcls_injector/output/fort.60',
#  '../templates/lcls_injector/output/fort.50',
#  '../templates/lcls_injector/output/fort.26',
#  '../templates/lcls_injector/output/fort.29',
#  '../templates/lcls_injector/output/fort.18',
#  '../templates/lcls_injector/output/fort.27']

# %%
# Load one file
load_fort(fortfiles[0])
# Out:
# 30 Fourth root of the fourth moments of the beam distribution
# {'t': array([0.00000e+00, 1.75000e-13, 3.50000e-13, ..., 1.52315e-08,
#         1.52340e-08, 1.52365e-08]),
#  'z': array([-2.1936551e-06, -2.0898184e-06, -1.9855704e-06, ...,
#          4.5518048e+00,  4.5525542e+00,  4.5533037e+00]),
#  'x_moment4': array([0.00033051, 0.00033051, 0.00033051, ..., 0.00050102, 0.00050111,
#         0.00050121]),
#  'GBx_moment4': array([0.00117378, 0.00117378, 0.00117378, ..., 0.01616553, 0.01616561,
#         0.0161657 ]),
#  'y_moment4': array([0.00033053, 0.00033053, 0.00033053, ..., 0.00050202, 0.00050211,
#         0.00050221]),
#  'GBy_moment4': array([0.00117538, 0.00117538, 0.00117538, ..., 0.01615309, 0.01615318,
#         0.01615326]),
#  'z_moment4': array([1.0660044e-06, 1.0664017e-06, 1.0707963e-06, ..., 6.9503560e-04,
#         6.9503563e-04, 6.9503566e-04]),
#  'GBz_moment4': array([2.0843554e-06, 5.3676672e-04, 1.4171274e-03, ..., 1.2778914e-01,
#         1.2816515e-01, 1.2787786e-01])}

# %%
# Load many

# %%
data = load_many_fort(opath, verbose=True)
# Out:
# 30 Fourth root of the fourth moments of the beam distribution
# skipping: ../templates/lcls_injector/output/fort.40
# 25 RMS Y information
# skipping: ../templates/lcls_injector/output/fort.70
# 24 RMS X information
# skipping: ../templates/lcls_injector/output/fort.60
# skipping: ../templates/lcls_injector/output/fort.50
# 26 RMS Z information
# 29 Cube root of third moments of the beam distribution
# 18 Time and energy
# 27 Max amplitude information

# %% [markdown]
# # Plot

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource
from bokeh.layouts import column
from bokeh.models.widgets import Dropdown
from impact.parsers import UNITS
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1103">Loading BokehJS ...</span>
#     </div>

# %%
ds = ColumnDataSource(data)

# %%
def plot1(y_axis, x_axis='z', source=ds):
    yunit = UNITS[y_axis]
    ylabel = y_axis+' ('+yunit+')'
    
    xunit = UNITS[x_axis]
    xlabel = x_axis+' ('+xunit+')'
    p = figure(plot_width=600, plot_height=200, x_axis_label=xlabel, y_axis_label=ylabel)
    p.line( x_axis, y_axis, source=source, color='red')
    return p
show(plot1('x_normemit') )
# Out:
#   <div class="bk-root" id="574d8958-c054-4a6a-a859-744e159296f7" data-root-id="1459"></div>

# %%
data.keys()
# Out:
# dict_keys(['t', 'z', 'x_moment4', 'GBx_moment4', 'y_moment4', 'GBy_moment4', 'z_moment4', 'GBz_moment4', 'y_centroid', 'y_rms', 'GBy_centroid', 'GBy_rms', 'y_twiss', 'y_normemit', 'x_centroid', 'x_rms', 'GBx_centroid', 'GBx_rms', 'x_twiss', 'x_normemit', 'z_centroid', 'z_rms', 'GBz_centroid', 'GBz_rms', 'z_twiss', 'z_normemit', 'x_moment3', 'GBx_moment3', 'y_moment3', 'GBy_moment3', 'z_moment3', 'GBz_moment3', 'gamma', 'E_kinetic', 'beta', 'r_max', 'deltaGamma_rms', 'x_max', 'GBx_max', 'y_max', 'GBy_max', 'z_max', 'GBz_max'])

# %%
infile =  '../templates/lcls_injector/ImpactT.in'
dat= parse_impact_input(infile)   
header = dat['header']
lattice = dat['lattice']
